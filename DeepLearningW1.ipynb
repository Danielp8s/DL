# %%
#Librerias usadas
import pandas as pd
from google.colab import files

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_file = '/content/drive/MyDrive/LISTADO_DE_PREDIDOS_MUNICIPIO_DE_BOYACA-BOYACA_20240806.csv'

data = pd.read_csv(data_file)
print(data)
# Out:
#               Codigo  Vereda                          Dirección    Avaluo  \
# 0           10001000       1       SAN ISIDRO VDA HUERTAS CHICA   6810000
# 1           10002000       1      LA ESPERANZA VDA HUERTA CHICA   9200000
# 2           10003000       1  LA VEGA SANTA CATALINA VDA HUERTA   8011000
# 3           10003000       1  LA VEGA SANTA CATALINA VDA HUERTA   8011000
# 4           10003000       1  LA VEGA SANTA CATALINA VDA HUERTA   8011000
# ...              ...     ...                                ...       ...
# 8626  10000360008000      36                          K 2 6 185  10065000
# 8627  10000360008000      36                          K 2 6 185  10065000
# 8628  10000360008000      36                          K 2 6 185  10065000
# 8629  10000360009000      36                     K 3 6-133 Lo 1   3838000
# 8630  10000360011000      36                   K 3 6 90 82 Lo 1   4977000
#
#                              Predial
# 0     151040000000000000000000000000
# ...

# %%
data.head(10)
# Out:
#      Codigo  Vereda                          Dirección   Avaluo  \
# 0  10001000       1       SAN ISIDRO VDA HUERTAS CHICA  6810000
# 1  10002000       1      LA ESPERANZA VDA HUERTA CHICA  9200000
# 2  10003000       1  LA VEGA SANTA CATALINA VDA HUERTA  8011000
# 3  10003000       1  LA VEGA SANTA CATALINA VDA HUERTA  8011000
# 4  10003000       1  LA VEGA SANTA CATALINA VDA HUERTA  8011000
# 5  10003000       1  LA VEGA SANTA CATALINA VDA HUERTA  8011000
# 6  10003000       1  LA VEGA SANTA CATALINA VDA HUERTA  8011000
# 7  10003000       1  LA VEGA SANTA CATALINA VDA HUERTA  8011000
# 8  10003000       1  LA VEGA SANTA CATALINA VDA HUERTA  8011000
# 9  10003000       1  LA VEGA SANTA CATALINA VDA HUERTA  8011000
#
#                           Predial
# 0  151040000000000000000000000000
# 1  151040000000000000000000000000
# 2  151040000000000000000000000000
# 3  151040000000000000000000000000
# 4  151040000000000000000000000000
# 5  151040000000000000000000000000
# ...

# %%
# Se elimina la columna Predial ya que era la misma
data = data[['Codigo', 'Vereda', 'Dirección', 'Avaluo']]

# %%
# Añade columnda de impuesto_predial
data['impuesto_predial'] = data['Avaluo'] * 0.005

# %%
data.to_csv('processed_dataset.csv', index=False)

# Descargar el archivo CSV al sistema local
files.download('processed_dataset.csv')

# %%
newdata_file = 'processed_dataset.csv'

newdata = pd.read_csv(newdata_file)

# %%
newdata.head(10)
# Out:
#      Codigo  Vereda                          Dirección   Avaluo  \
# 0  10001000       1       SAN ISIDRO VDA HUERTAS CHICA  6810000
# 1  10002000       1      LA ESPERANZA VDA HUERTA CHICA  9200000
# 2  10003000       1  LA VEGA SANTA CATALINA VDA HUERTA  8011000
# 3  10003000       1  LA VEGA SANTA CATALINA VDA HUERTA  8011000
# 4  10003000       1  LA VEGA SANTA CATALINA VDA HUERTA  8011000
# 5  10003000       1  LA VEGA SANTA CATALINA VDA HUERTA  8011000
# 6  10003000       1  LA VEGA SANTA CATALINA VDA HUERTA  8011000
# 7  10003000       1  LA VEGA SANTA CATALINA VDA HUERTA  8011000
# 8  10003000       1  LA VEGA SANTA CATALINA VDA HUERTA  8011000
# 9  10003000       1  LA VEGA SANTA CATALINA VDA HUERTA  8011000
#
#    impuesto_predial
# 0           34050.0
# 1           46000.0
# 2           40055.0
# 3           40055.0
# 4           40055.0
# 5           40055.0
# 6           40055.0
# 7           40055.0
# 8           40055.0
# 9           40055.0

# %%
# Eliminar filas duplicadas (Codigo)
newdata.drop_duplicates(subset=['Codigo'], inplace=True)

newdata.head(10)
# Out:
#       Codigo  Vereda                          Dirección   Avaluo  \
# 0   10001000       1       SAN ISIDRO VDA HUERTAS CHICA  6810000
# 1   10002000       1      LA ESPERANZA VDA HUERTA CHICA  9200000
# 2   10003000       1  LA VEGA SANTA CATALINA VDA HUERTA  8011000
# 10  10004000       1            ROPERO VDA HUERTA CHICA  4160000
# 11  10005000       1         PENA LIZA VDA HUERTA CHICA  2229000
# 18  10006000       1            ESPANA VDA HUERTA CHICA  2024000
# 19  10007000       1          GIRARDOT VDA HUERTA CHICA  1392000
# 20  10008000       1          LA PALMA VDA HUERTA CHICA  2881000
# 21  10009000       1      CAMPOHERMOSO VDA HUERTA CHICA   690000
# 24  10010000       1         EL CURUBO VDA HUERTA CHICA   804000
#
#     impuesto_predial
# 0            34050.0
# 1            46000.0
# 2            40055.0
# 10           20800.0
# 11           11145.0
# 18           10120.0
# 19            6960.0
# 20           14405.0
# 21            3450.0
# 24            4020.0
